# %%
#worldcloud 라이브러리 로드
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = '''pwpoqwiepqwosl;akjdflksajdfzxm,cnv,mxczvnlaskdfjsaldfkji weiopruweroiqwlkrjiou
woeiurwoeirujq qweqoipweulkr oiweurlksj'''



wc = WordCloud().generate(text)

# %%
plt.imshow(wc)
plt.axis('off')
plt.show()
