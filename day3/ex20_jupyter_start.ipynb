# %% [markdown]
# # 주피터 노트북 시작
# - 마크 다운 쉘은 일반 md 파일에서 작성하는 것과 동일
# - 구글과 같이 웹사이트 링크 사용가능
# - 주피터 노트북의 경로는 해당위치 부터 시작

# %%
print("hello")
# Out:
# hello

# %%
num = int(input("정수입력"))

# %%
print(num)
# Out:
# 69

# %% [markdown]
# - 변수명만 적어도 출력가능
# - 근데 여러개해도 하나만 출력됨

# %%
num
num*10
# Out:
# 690

# %% [markdown]
# - 그래서 여러줄 하려면 print 써야함

# %%
print(num)
print(num*10) #print를 적으면 여러개 가능
# Out:
# 69
# 690
